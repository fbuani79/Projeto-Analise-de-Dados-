# %% [markdown]
# #Analise de produtos mais vendidos CS

# %%
import pandas as pd
tabela = pd.read_excel("/content/drive/MyDrive/Analise de estoque Black 20212.xlsx")
tabela = tabela.drop("RESERVA", axis=1)
display(tabela)
# Out:
#             COD                                          DESCRICAO  \
# 0      00029992             JOGO DE SOQUETES 1/4 COM 41 PEÇAS 5520
# 1      00001169  MANGUEIRA BORRACHA 5/16" PRETA - PNEUMATICA 35...
# 2      00001398                         CADEIRA CHARLES EAMES - CD
# 3      00025617  COPO P/ CAFE PAREDE DUPLA BOROSSILICATO 80ML 6138
# 4      00021567  CADEIRA PRAIA VARANDA ALTA ALUMÍNIO CAD0047 BO...
# ...         ...                                                ...
# 21126  00028594  LAVADORA ALTA PRESSAO 2400PSI 1900W - ULTRA PR...
# 21127  00030834  ROCADEIRA MULTIFUNCIONAL 18V S/BATERIA DUX60Z ...
# 21128  00007630                   LAVADORA ALTA PRESSAO 330LBF 2HP
# 21129  00004423              COLETOR DE PO 2ENTRADAS 1RESERVATORIO
# 21130  00006675                     ESQUADRO MAGNETICO 12KG - 4325
#
#                            DEPTO       DIVISAO     CATEGORIA  \
# 0          FERRAMENTAS - MANUAIS   FERRAMENTAS   FERRAMENTAS
# ...

# %%
tabela = tabela.dropna()
display(tabela.info())

display(tabela.describe().round(1))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 0 to 17
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   COD            9 non-null      object
#  1   DESCRICAO      9 non-null      object
#  2   DEPTO          9 non-null      object
#  3   DIVISAO        9 non-null      object
#  4   CATEGORIA      9 non-null      object
#  5   TIPO           9 non-null      object
#  6   MARCA          9 non-null      object
#  7   RANK           9 non-null      int64
#  8   QTDE VENDIDA   9 non-null      int64
#  9   VALOR VENDIDO  9 non-null      float64
#  10  % TOTAL        9 non-null      float64
#  11  % ACUM         9 non-null      float64
#  12  EST DISP       9 non-null      float64
#  13  EST TOTAL      9 non-null      float64
#  14  Estoque        9 non-null      object
# dtypes: float64(5), int64(2), object(8)
# memory usage: 1.1+ KB
# None
# ...

# %%
tabela.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21131 entries, 0 to 21130
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   COD            21131 non-null  object
#  1   DESCRICAO      21131 non-null  object
#  2   DEPTO          21131 non-null  object
#  3   DIVISAO        21131 non-null  object
#  4   CATEGORIA      21131 non-null  object
#  5   TIPO           21131 non-null  object
#  6   MARCA          21131 non-null  object
#  7   RANK           21131 non-null  int64
#  8   QTDE VENDIDA   21131 non-null  int64
#  9   VALOR VENDIDO  21131 non-null  float64
#  10  % TOTAL        21131 non-null  float64
#  11  % ACUM         21131 non-null  float64
#  12  EST DISP       21131 non-null  float64
#  13  RESERVA        21131 non-null  int64
#  14  EST TOTAL      21131 non-null  float64
#  15  Estoque        9 non-null      object
# dtypes: float64(5), int64(3), object(8)
# memory usage: 2.6+ MB

# %%
tabela.describe()
# Out:
#                RANK  QTDE VENDIDA  VALOR VENDIDO       % TOTAL        % ACUM  \
# count  21131.000000  21131.000000   21131.000000  21131.000000  21131.000000
# mean    1270.031234      0.821920     140.600677      0.004732     99.962407
# std      184.344220     17.125863    2015.864632      0.067851      4.351365
# min        1.000000     -4.000000   -4269.160000     -0.143693      3.329654
# 25%     1311.000000      0.000000       0.000000      0.000000    100.567772
# 50%     1311.000000      0.000000       0.000000      0.000000    100.567772
# 75%     1311.000000      0.000000       0.000000      0.000000    100.567772
# max     1334.000000   1725.000000   98925.130000      3.329654    100.567772
#
#            EST DISP       RESERVA     EST TOTAL
# count  21131.000000  21131.000000  21131.000000
# mean      18.783011      0.320808     19.102967
# std      220.895385     10.967815    222.857797
# min     -113.000000     -1.000000    -47.000000
# ...

# %%
tabela['MARCA']
# Out:
# 0                    TITANIUM
# 1                     BR FLEX
# 2                  CDS DESIGN
# 3                  MIMO STYLE
# 4        BOTAFOGO LAR & LAZER
#                  ...
# 21126                     WAP
# 21127                  MAKITA
# 21128              CHIAPERINI
# 21129                 MAKSIWA
# 21130                TITANIUM
# Name: MARCA, Length: 21131, dtype: object

# %% [markdown]
# #Acima vemos a marca mais vendida

# %%
tabela['QTDE VENDIDA']
# Out:
# 0        1725
# 1         809
# 2         768
# 3         671
# 4         660
#          ...
# 21126      -1
# 21127      -1
# 21128      -1
# 21129      -1
# 21130      -4
# Name: QTDE VENDIDA, Length: 21131, dtype: int64

# %% [markdown]
# #Acima vemos a Quantidade vendida das marcas mais vendidas

# %%
import plotly.express as px

for coluna in tabela:
  
  grafico = px.histogram(tabela, x=coluna, color="MARCA")
  grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

for coluna in tabela:
  
  grafico = px.histogram(tabela, x=coluna, color="TIPO")
  grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

for coluna in tabela:
  
  grafico = px.histogram(tabela, x=coluna, color="QTDE VENDIDA")
  grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

for coluna in tabela:
  
  grafico = px.histogram(tabela, x=coluna, color="TIPO")
  grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
